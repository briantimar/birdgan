# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import glob
# Out:
# /home/brian/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from preprocess_data import preprocess_image

# %%
tf.enable_eager_execution()

# %%
dr = "data/images/001_Black_footed_Albatross/"
fnames = glob.glob(dr+"*")
f=fnames[10]

# %%
im = preprocess_image(f)

# %%
from preprocess_data import undo_normalization

# %%
rsc = undo_normalization(im).numpy().astype(np.uint8)

# %%
# %matplotlib inline
plt.imshow(rsc)
