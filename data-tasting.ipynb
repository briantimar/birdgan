# %%
import numpy as np
import glob
from scipy.ndimage import imread
import matplotlib.pyplot as plt

# %%
from load_data import crop, downsample

# %%
dr = "data/images/001.Black_footed_albatross/"

# %%
fnames = glob.glob(dr+"*")

# %%
fname = fnames[0]

# %%
im=imread(fname)

# %%
im.shape
# Out:
# (500, 375, 3)

# %%
# %matplotlib inline
plt.imshow(im)

# %%
im_ds = downsample(im)

# %%
plt.imshow(im_ds)

# %%
imc = crop(im_ds)

# %%
plt.imshow(imc)
